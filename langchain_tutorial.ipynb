# %%
# !pip install langchain
# !pip install langchain-huggingface==0.0.1 accelerate bitsandbytes
#citation https://medium.com/@scholarly360/langchain-huggingface-complete-guide-on-colab-dfafe04fe661
# https://huggingface.co/blog/langchain

# %%
# code to load the model

from langchain_huggingface import HuggingFacePipeline

llm = HuggingFacePipeline.from_model_id(
    model_id="microsoft/Phi-3-mini-4k-instruct",
    task="text-generation",
    pipeline_kwargs={
        "max_new_tokens": 100,
        "top_k": 50,
        "temperature": 0.1,
    },
)
llm.invoke("Hugging Face is")
# Out:
# 2024-11-11 03:25:34.076115: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1731295534.095069     474 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1731295534.101001     474 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-11 03:25:34.119765: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
from langchain_huggingface.embeddings import HuggingFaceEmbeddings
# !pip install tf-keras

#using the model with a backwards compitable version of keras
model_name = "mixedbread-ai/mxbai-embed-large-v1"
hf_embeddings = HuggingFaceEmbeddings(
    model_name=model_name,
)
texts = ["Hello, world!", "How are you?"]
hf_embeddings.embed_documents(texts)
# Out:
# ...
# [[0.3059691786766052,
#   0.7907293438911438,
#   0.009807423688471317,
#   -0.15764284133911133,
#   -0.8023923635482788,
#   0.1497568041086197,
#   1.2789499759674072,
#   0.7509118318557739,
#   0.8415453433990479,
#   0.042983122169971466,
#   0.12561316788196564,
#   0.08207769691944122,
#   -0.09308482706546783,
#   0.12744812667369843,
#   -0.8875035047531128,
#   -0.04624263197183609,
#   -0.16150794923305511,
#   -0.6829600930213928,
#   -0.7650359272956848,
#   0.033894918859004974,
#   -0.3529987037181854,
#   0.37652015686035156,
#   -1.2507708072662354,
#   -0.3606584668159485,
#   0.21749347448349,
#   0.3550869822502136,
#   0.8079593777656555,
#   -0.07037470489740372,
#   0.8502591252326965,
#   0.8510406017303467,
#   -0.2966591715812683,
#   0.16541160643100739,
#   -0.2534836530685425,
#   -1.0056419372558594,
#   -0.4668940603733063,
#   -0.18940308690071106,
#   0.40086525678634644,
#   -0.30468806624412537,
#   -0.5170358419418335,
#   -0.6449673771858215,
# ...

# %%
# hugging face langchain works now to learn about creating rags
